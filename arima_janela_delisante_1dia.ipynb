# %% [markdown]
# ARIMA - CLIMA JANELA DESLISANTE 1 - PREVISÃO 1 DIA

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')
# Preparação dos dados
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
train = data[:'2021']
test = data['2022':]
ts_train = train['Preco_Real']
ts_test = test['Preco_Real']

# Inicialização do modelo ARIMA otimizado com os dados de treino
optimized_model = ARIMA(ts_train, order=(5, 1, 0))
optimized_model_fit = optimized_model.fit()

# Previsões usando janela deslizante
optimized_predictions = []
for new_obs in ts_test:
    optimized_forecast = optimized_model_fit.get_forecast(steps=1)
    optimized_predictions.append(optimized_forecast.predicted_mean.iloc[0])
    optimized_model_fit = optimized_model_fit.extend([new_obs])

# Cálculo das métricas de desempenho
optimized_mae = mean_absolute_error(ts_test, optimized_predictions)
optimized_rmse = mean_squared_error(ts_test, optimized_predictions, squared=False)
optimized_r2 = r2_score(ts_test, optimized_predictions)

# Diferença entre o real e o previsto no último dia
last_actual = ts_test.iloc[-1]
last_predicted = optimized_predictions[-1]
difference_in_points = last_actual - last_predicted

# Criação de um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Actual': ts_test.tail(1),
    'Predicted': last_predicted,
    'Difference': difference_in_points
})

# Exibição das métricas e do DataFrame de comparação
metrics = {
    'Mean Absolute Error': optimized_mae,
    'Root Mean Squared Error': optimized_rmse,
    'R^2 Score': optimized_r2,
    'Difference in Points (Last Day)': difference_in_points
}

# Plotagem do gráfico
plt.figure(figsize=(12,6))
plt.plot(ts_train.index, ts_train, label='Train')
plt.plot(ts_test.index, ts_test, label='Test')
plt.plot(ts_test.index, optimized_predictions, label='Optimized Rolling Forecast', color='red')
plt.legend()
plt.title('Optimized ARIMA Rolling Forecast vs Actual')
plt.show()

metrics, comparison_df
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ARIMA - IBOVESPA JANELA DESLISANTE 1 - PREVISÃO 1 DIA

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/ibovespa.csv')
# Preparação dos dados
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
train = data[:'2021']
test = data['2022':]
ts_train = train['Preco_Real']
ts_test = test['Preco_Real']

# Inicialização do modelo ARIMA otimizado com os dados de treino
optimized_model = ARIMA(ts_train, order=(5, 1, 0))
optimized_model_fit = optimized_model.fit()

# Previsões usando janela deslizante
optimized_predictions = []
for new_obs in ts_test:
    optimized_forecast = optimized_model_fit.get_forecast(steps=1)
    optimized_predictions.append(optimized_forecast.predicted_mean.iloc[0])
    optimized_model_fit = optimized_model_fit.extend([new_obs])

# Cálculo das métricas de desempenho
optimized_mae = mean_absolute_error(ts_test, optimized_predictions)
optimized_rmse = mean_squared_error(ts_test, optimized_predictions, squared=False)
optimized_r2 = r2_score(ts_test, optimized_predictions)

# Diferença entre o real e o previsto no último dia
last_actual = ts_test.iloc[-1]
last_predicted = optimized_predictions[-1]
difference_in_points = last_actual - last_predicted

# Criação de um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Actual': ts_test.tail(1),
    'Predicted': last_predicted,
    'Difference': difference_in_points
})

# Exibição das métricas e do DataFrame de comparação
metrics = {
    'Mean Absolute Error': optimized_mae,
    'Root Mean Squared Error': optimized_rmse,
    'R^2 Score': optimized_r2,
    'Difference in Points (Last Day)': difference_in_points
}

# Plotagem do gráfico
plt.figure(figsize=(12,6))
plt.plot(ts_train.index, ts_train, label='Train')
plt.plot(ts_test.index, ts_test, label='Test')
plt.plot(ts_test.index, optimized_predictions, label='Optimized Rolling Forecast', color='red')
plt.legend()
plt.title('Optimized ARIMA Rolling Forecast vs Actual')
plt.show()

metrics, comparison_df
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ARIMA - SELIC JANELA DESLISANTE 1 - PREVISÃO 1 DIA

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/selic.csv')
# Preparação dos dados
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
train = data[:'2021']
test = data['2022':]
ts_train = train['Preco_Real']
ts_test = test['Preco_Real']

# Inicialização do modelo ARIMA otimizado com os dados de treino
optimized_model = ARIMA(ts_train, order=(5, 1, 0))
optimized_model_fit = optimized_model.fit()

# Previsões usando janela deslizante
optimized_predictions = []
for new_obs in ts_test:
    optimized_forecast = optimized_model_fit.get_forecast(steps=1)
    optimized_predictions.append(optimized_forecast.predicted_mean.iloc[0])
    optimized_model_fit = optimized_model_fit.extend([new_obs])

# Cálculo das métricas de desempenho
optimized_mae = mean_absolute_error(ts_test, optimized_predictions)
optimized_rmse = mean_squared_error(ts_test, optimized_predictions, squared=False)
optimized_r2 = r2_score(ts_test, optimized_predictions)

# Diferença entre o real e o previsto no último dia
last_actual = ts_test.iloc[-1]
last_predicted = optimized_predictions[-1]
difference_in_points = last_actual - last_predicted

# Criação de um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Actual': ts_test.tail(1),
    'Predicted': last_predicted,
    'Difference': difference_in_points
})

# Exibição das métricas e do DataFrame de comparação
metrics = {
    'Mean Absolute Error': optimized_mae,
    'Root Mean Squared Error': optimized_rmse,
    'R^2 Score': optimized_r2,
    'Difference in Points (Last Day)': difference_in_points
}

# Plotagem do gráfico
plt.figure(figsize=(12,6))
plt.plot(ts_train.index, ts_train, label='Train')
plt.plot(ts_test.index, ts_test, label='Test')
plt.plot(ts_test.index, optimized_predictions, label='Optimized Rolling Forecast', color='red')
plt.legend()
plt.title('Optimized ARIMA Rolling Forecast vs Actual')
plt.show()

metrics, comparison_df
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ARIMA - DOLAR JANELA DESLISANTE 1 - PREVISÃO 1 DIA

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')
# Preparação dos dados
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
train = data[:'2021']
test = data['2022':]
ts_train = train['Preco_Real']
ts_test = test['Preco_Real']

# Inicialização do modelo ARIMA otimizado com os dados de treino
optimized_model = ARIMA(ts_train, order=(5, 1, 0))
optimized_model_fit = optimized_model.fit()

# Previsões usando janela deslizante
optimized_predictions = []
for new_obs in ts_test:
    optimized_forecast = optimized_model_fit.get_forecast(steps=1)
    optimized_predictions.append(optimized_forecast.predicted_mean.iloc[0])
    optimized_model_fit = optimized_model_fit.extend([new_obs])

# Cálculo das métricas de desempenho
optimized_mae = mean_absolute_error(ts_test, optimized_predictions)
optimized_rmse = mean_squared_error(ts_test, optimized_predictions, squared=False)
optimized_r2 = r2_score(ts_test, optimized_predictions)

# Diferença entre o real e o previsto no último dia
last_actual = ts_test.iloc[-1]
last_predicted = optimized_predictions[-1]
difference_in_points = last_actual - last_predicted

# Criação de um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Actual': ts_test.tail(1),
    'Predicted': last_predicted,
    'Difference': difference_in_points
})

# Exibição das métricas e do DataFrame de comparação
metrics = {
    'Mean Absolute Error': optimized_mae,
    'Root Mean Squared Error': optimized_rmse,
    'R^2 Score': optimized_r2,
    'Difference in Points (Last Day)': difference_in_points
}

# Plotagem do gráfico
plt.figure(figsize=(12,6))
plt.plot(ts_train.index, ts_train, label='Train')
plt.plot(ts_test.index, ts_test, label='Test')
plt.plot(ts_test.index, optimized_predictions, label='Optimized Rolling Forecast', color='red')
plt.legend()
plt.title('Optimized ARIMA Rolling Forecast vs Actual')
plt.show()

metrics, comparison_df
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %% [markdown]
# ARIMA - BASE TODA JANELA DESLISANTE 1 - PREVISÃO 1 DIA

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import pandas as pd
data= pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/base_completa.csv')
# Preparação dos dados
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)
data.sort_index(inplace=True)
train = data[:'2021']
test = data['2022':]
ts_train = train['Preco_Real']
ts_test = test['Preco_Real']

# Inicialização do modelo ARIMA otimizado com os dados de treino
optimized_model = ARIMA(ts_train, order=(5, 1, 0))
optimized_model_fit = optimized_model.fit()

# Previsões usando janela deslizante
optimized_predictions = []
for new_obs in ts_test:
    optimized_forecast = optimized_model_fit.get_forecast(steps=1)
    optimized_predictions.append(optimized_forecast.predicted_mean.iloc[0])
    optimized_model_fit = optimized_model_fit.extend([new_obs])

# Cálculo das métricas de desempenho
optimized_mae = mean_absolute_error(ts_test, optimized_predictions)
optimized_rmse = mean_squared_error(ts_test, optimized_predictions, squared=False)
optimized_r2 = r2_score(ts_test, optimized_predictions)

# Diferença entre o real e o previsto no último dia
last_actual = ts_test.iloc[-1]
last_predicted = optimized_predictions[-1]
difference_in_points = last_actual - last_predicted

# Criação de um DataFrame para comparação
comparison_df = pd.DataFrame({
    'Actual': ts_test.tail(1),
    'Predicted': last_predicted,
    'Difference': difference_in_points
})

# Exibição das métricas e do DataFrame de comparação
metrics = {
    'Mean Absolute Error': optimized_mae,
    'Root Mean Squared Error': optimized_rmse,
    'R^2 Score': optimized_r2,
    'Difference in Points (Last Day)': difference_in_points
}

# Plotagem do gráfico
plt.figure(figsize=(12,6))
plt.plot(ts_train.index, ts_train, label='Train')
plt.plot(ts_test.index, ts_test, label='Test')
plt.plot(ts_test.index, optimized_predictions, label='Optimized Rolling Forecast', color='red')
plt.legend()
plt.title('Optimized ARIMA Rolling Forecast vs Actual')
plt.show()

metrics, comparison_df
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import time

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

df = pd.DataFrame({
    'Date': pd.date_range(start='2021-01-01', periods=150, freq='D'),
    'Preco_Real': np.random.rand(150).cumsum()  # Random cumulative data as an example
})
df['Date'] = pd.to_datetime(df['Date'])  # Ensure 'Date' column is datetime type

# Function to perform walk-forward validation
def walk_forward_validation(data, start_date, end_date):
    predictions = []
    actuals = []
    prediction_dates = []

    # Prepare the training and validation datasets
    training_data = data[data['Date'] < start_date]['Preco_Real'].tolist()
    validation_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]
    
    total_days = validation_data.shape[0]
    
    # Train and make predictions one step at a time
    for i, row in validation_data.iterrows():
        model = ARIMA(training_data, order=(5,1,0))  # Example ARIMA order
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        actual = row['Preco_Real']
        
        predictions.append(yhat)
        actuals.append(actual)
        prediction_dates.append(row['Date'])

        # Progress output
        progress = ((i + 1) / total_days) * 100
        print(f"Processing date {row['Date'].strftime('%Y-%m-%d')} - Progress: {progress:.2f}%")
        
        # Add the actual value to the training data for the next iteration
        training_data.append(actual)
    
    return prediction_dates, actuals, predictions

# Define the start and end dates for the validation period
start_date = datetime(2021, 5, 1)
end_date = datetime(2021, 5, 30)

# Perform walk-forward validation
prediction_dates, actuals, predictions = walk_forward_validation(df, start_date, end_date)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
mape = np.mean(np.abs((np.array(actuals) - np.array(predictions)) / np.array(actuals))) * 100
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
print(f'R-squared: {r2}')


# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
results.head()
# Out:
# Processing date 2021-05-01 - Progress: 403.33%
# Processing date 2021-05-02 - Progress: 406.67%
# Processing date 2021-05-03 - Progress: 410.00%
# Processing date 2021-05-04 - Progress: 413.33%
# Processing date 2021-05-05 - Progress: 416.67%
# Processing date 2021-05-06 - Progress: 420.00%
# Processing date 2021-05-07 - Progress: 423.33%
# Processing date 2021-05-08 - Progress: 426.67%
# Processing date 2021-05-09 - Progress: 430.00%
# Processing date 2021-05-10 - Progress: 433.33%
# Processing date 2021-05-11 - Progress: 436.67%
# Processing date 2021-05-12 - Progress: 440.00%
# Processing date 2021-05-13 - Progress: 443.33%
# Processing date 2021-05-14 - Progress: 446.67%
# Processing date 2021-05-15 - Progress: 450.00%
# Processing date 2021-05-16 - Progress: 453.33%
# Processing date 2021-05-17 - Progress: 456.67%
# Processing date 2021-05-18 - Progress: 460.00%
# Processing date 2021-05-19 - Progress: 463.33%
# Processing date 2021-05-20 - Progress: 466.67%
# ...

# %%
pip install statsmodels
# Out:
# ...
# WARNING: Ignoring invalid distribution -2o (c:\users\milen\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -2o (c:\users\milen\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import time

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

df = pd.DataFrame({
    'Date': pd.date_range(start='2022-01-01', periods=150, freq='D'),
    'Preco_Real': np.random.rand(150).cumsum()  # Random cumulative data as an example
})
df['Date'] = pd.to_datetime(df['Date'])  # Ensure 'Date' column is datetime type

# Function to perform walk-forward validation
def walk_forward_validation(data, start_date, end_date):
    predictions = []
    actuals = []
    prediction_dates = []

    # Prepare the training and validation datasets
    training_data = data[data['Date'] < start_date]['Preco_Real'].tolist()
    validation_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]
    
    total_days = validation_data.shape[0]
    
    # Train and make predictions one step at a time
    for i, row in validation_data.iterrows():
        model = ARIMA(training_data, order=(5,1,0))  # Example ARIMA order
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        actual = row['Preco_Real']
        
        predictions.append(yhat)
        actuals.append(actual)
        prediction_dates.append(row['Date'])

        # Progress output
        progress = ((i + 1) / total_days) * 100
        print(f"Processing date {row['Date'].strftime('%Y-%m-%d')} - Progress: {progress:.2f}%")
        
        # Add the actual value to the training data for the next iteration
        training_data.append(actual)
    
    return prediction_dates, actuals, predictions

# Define the start and end dates for the validation period
start_date = datetime(2022, 1, 1)
end_date = datetime(2023, 8, 30)

# Perform walk-forward validation
prediction_dates, actuals, predictions = walk_forward_validation(df, start_date, end_date)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
mape = np.mean(np.abs((np.array(actuals) - np.array(predictions)) / np.array(actuals))) * 100
r2 = r2_score(actuals, predictions)
# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
print(f'R-squared: {r2}')


# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
results.head()
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:3747: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\_methods.py:261: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
from datetime import datetime
import time

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/base_completa.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation
def walk_forward_validation(data, start_date, end_date):
    predictions = []
    actuals = []
    prediction_dates = []

    # Prepare the training and validation datasets
    training_data = data[data['Date'] < start_date]['Preco_Real'].tolist()
    validation_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]
    
    total_days = validation_data.shape[0]
    
    # Train and make predictions one step at a time
    for i, row in validation_data.iterrows():
        model = ARIMA(training_data, order=(6,1,0))  # Example ARIMA order
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        actual = row['Preco_Real']
        
        predictions.append(yhat)
        actuals.append(actual)
        prediction_dates.append(row['Date'])

        # Progress output
        progress = ((i + 1) / total_days) * 100
        print(f"Processing date {row['Date'].strftime('%Y-%m-%d')} - Progress: {progress:.2f}%")
        
        # Add the actual value to the training data for the next iteration
        training_data.append(actual)
    
    return prediction_dates, actuals, predictions

# Define the start and end dates for the validation period
start_date = datetime(2022, 1, 1)
end_date = datetime(2023, 8, 1)

# Perform walk-forward validation
prediction_dates, actuals, predictions = walk_forward_validation(df, start_date, end_date)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
mape = np.mean(np.abs((np.array(actuals) - np.array(predictions)) / np.array(actuals))) * 100
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
print(f'R-squared: {r2}')


# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
results.head()
# Out:
# Processing date 2022-01-03 - Progress: 949.24%
# Processing date 2022-01-04 - Progress: 949.49%
# Processing date 2022-01-05 - Progress: 949.75%
# Processing date 2022-01-06 - Progress: 950.00%
# Processing date 2022-01-07 - Progress: 950.25%
# Processing date 2022-01-10 - Progress: 950.51%
# Processing date 2022-01-11 - Progress: 950.76%
# Processing date 2022-01-12 - Progress: 951.01%
# Processing date 2022-01-13 - Progress: 951.26%
# Processing date 2022-01-14 - Progress: 951.52%
# Processing date 2022-01-17 - Progress: 951.77%
# Processing date 2022-01-18 - Progress: 952.02%
# Processing date 2022-01-19 - Progress: 952.27%
# Processing date 2022-01-20 - Progress: 952.53%
# Processing date 2022-01-21 - Progress: 952.78%
# Processing date 2022-01-24 - Progress: 953.03%
# Processing date 2022-01-25 - Progress: 953.28%
# Processing date 2022-01-26 - Progress: 953.54%
# Processing date 2022-01-27 - Progress: 953.79%
# Processing date 2022-01-28 - Progress: 954.04%
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
from datetime import datetime
import time

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation
def walk_forward_validation(data, start_date, end_date):
    predictions = []
    actuals = []
    prediction_dates = []

    # Prepare the training and validation datasets
    training_data = data[data['Date'] < start_date]['Preco_Real'].tolist()
    validation_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]
    
    total_days = validation_data.shape[0]
    
    # Train and make predictions one step at a time
    for i, row in validation_data.iterrows():
        model = ARIMA(training_data, order=(6,1,0))  # Example ARIMA order
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]
        actual = row['Preco_Real']
        
        predictions.append(yhat)
        actuals.append(actual)
        prediction_dates.append(row['Date'])

        # Progress output
        progress = ((i + 1) / total_days) * 100
        print(f"Processing date {row['Date'].strftime('%Y-%m-%d')} - Progress: {progress:.2f}%")
        
        # Add the actual value to the training data for the next iteration
        training_data.append(actual)
    
    return prediction_dates, actuals, predictions

# Define the start and end dates for the validation period
start_date = datetime(2022, 1, 1)
end_date = datetime(2023, 8, 1)

# Perform walk-forward validation
prediction_dates, actuals, predictions = walk_forward_validation(df, start_date, end_date)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
mape = np.mean(np.abs((np.array(actuals) - np.array(predictions)) / np.array(actuals))) * 100
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
print(f'R-squared: {r2}')


# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
results.head()
# Out:
# Processing date 2022-01-03 - Progress: 949.24%
# Processing date 2022-01-04 - Progress: 949.49%
# Processing date 2022-01-05 - Progress: 949.75%
# Processing date 2022-01-06 - Progress: 950.00%
# Processing date 2022-01-07 - Progress: 950.25%
# Processing date 2022-01-10 - Progress: 950.51%
# Processing date 2022-01-11 - Progress: 950.76%
# Processing date 2022-01-12 - Progress: 951.01%
# Processing date 2022-01-13 - Progress: 951.26%
# Processing date 2022-01-14 - Progress: 951.52%
# Processing date 2022-01-17 - Progress: 951.77%
# Processing date 2022-01-18 - Progress: 952.02%
# Processing date 2022-01-19 - Progress: 952.27%
# Processing date 2022-01-20 - Progress: 952.53%
# Processing date 2022-01-21 - Progress: 952.78%
# Processing date 2022-01-24 - Progress: 953.03%
# Processing date 2022-01-25 - Progress: 953.28%
# Processing date 2022-01-26 - Progress: 953.54%
# Processing date 2022-01-27 - Progress: 953.79%
# Processing date 2022-01-28 - Progress: 954.04%
# ...

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
from datetime import datetime

# Read the dataset from the CSV file
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)
# Function to perform walk-forward validation with multi-step forecasting
def walk_forward_validation(data, start_date, end_date, forecast_horizon=7):
    predictions = []
    actuals = []
    prediction_dates = []

    # Prepare the training and validation datasets
    training_data = data[data['Date'] < start_date]['Preco_Real'].tolist()
    validation_data = data[(data['Date'] >= start_date) & (data['Date'] <= end_date)]

    for i in range(0, len(validation_data), forecast_horizon):
        # Prepare the end index for the forecast period
        end_ix = i + forecast_horizon
        if end_ix > len(validation_data):
            end_ix = len(validation_data)
        actual = validation_data.iloc[i:end_ix]['Preco_Real'].tolist()

        # Forecast the next 'forecast_horizon' steps
        model = ARIMA(training_data, order=(5,1,0))  # Simplified model for demonstration
        model_fit = model.fit()
        yhat = model_fit.forecast(steps=forecast_horizon)[:len(actual)]

        # Append predictions and actuals
        predictions.extend(yhat)
        actuals.extend(actual)
        prediction_dates.extend(validation_data.iloc[i:end_ix]['Date'].tolist())

        # Add the actual values to the training data for the next iteration
        training_data.extend(actual)
    
    return prediction_dates, actuals, predictions

# Define the start and end dates for the validation period
start_date = datetime(2022, 1, 1)
end_date = datetime(2023, 8, 1)

# Perform walk-forward validation
forecast_horizon = 14  # Set this to how many days you want to forecast at each step
prediction_dates, actuals, predictions = walk_forward_validation(df, start_date, end_date, forecast_horizon)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
mape = np.mean(np.abs((np.array(actuals) - np.array(predictions)) / np.array(actuals))) * 100
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'MAPE: {mape}%')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Filter the results for a specific date range
specific_start_date = datetime(2023, 2, 1)
specific_end_date = datetime(2023, 2, 7)
specific_results = results[(results['Date'] >= specific_start_date) & (results['Date'] <= specific_end_date)]

# Display the specific results, including real values from the dataset
specific_results['Real'] = df[(df['Date'] >= specific_start_date) & (df['Date'] <= specific_end_date)]['Preco_Real'].values

print(specific_results)
# Out:
# MSE: 3331.8633409408344
# RMSE: 57.72229500756908
# MAE: 41.19023468304343
# MAPE: 3.6234152082819495%
# R-squared: 0.900395411696298
#           Date   Actual    Predicted     Real
# 272 2023-02-01  1104.47  1027.473930  1104.47
# 273 2023-02-02  1096.14  1027.456631  1096.14
# 274 2023-02-03  1079.90  1027.447012  1079.90
# 275 2023-02-06  1114.33  1027.451525  1114.33
# 276 2023-02-07  1123.64  1027.450650  1123.64
# C:\Users\milen\AppData\Local\Temp\ipykernel_7812\1134616500.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_results['Real'] = df[(df['Date'] >= specific_start_date) & (df['Date'] <= specific_end_date)]['Preco_Real'].values

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta
import numpy as np

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with a sliding window
def walk_forward_validation(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)

    for i in range(window_size, total_days):
        start_date = data.iloc[i - window_size]['Date']
        end_date = data.iloc[i]['Date']
        
        train_data = data[(data['Date'] >= start_date) & (data['Date'] < end_date)]['Preco_Real'].tolist()
        val_data = data.iloc[i]['Preco_Real']

        model = ARIMA(train_data, order=(5, 1, 0))
        model_fit = model.fit()
        yhat = model_fit.forecast()[0]

        predictions.append(yhat)
        actuals.append(val_data)
        prediction_dates.append(data.iloc[i]['Date'])

    return prediction_dates, actuals, predictions

# Define the window size for the sliding window (e.g., 30 days)
window_size = 30

# Perform walk-forward validation with the sliding window
prediction_dates, actuals, predictions = walk_forward_validation(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# MSE: 92.11575407171222
# RMSE: 9.597695247907813
#         Date  Actual   Predicted
# 0 2007-01-17  283.82  284.372456
# 1 2007-01-18  282.37  284.335683
# 2 2007-01-19  281.16  282.645710
# 3 2007-01-22  279.65  281.028033
# 4 2007-01-23  276.38  280.100624

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from datetime import datetime, timedelta
import numpy as np

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with a fixed-size window
def walk_forward_validation(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].tolist()
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(val_data) > 0:
            val_data = val_data[0]
            model = ARIMA(train_data, order=(5, 1, 0))
            model_fit = model.fit()
            yhat = model_fit.forecast()[0]

            predictions.append(yhat)
            actuals.append(val_data)
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the sliding window (e.g., 30 days)
window_size = 30

# Perform walk-forward validation with the specified test period
prediction_dates, actuals, predictions = walk_forward_validation(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())
# Out:
# c:\Users\milen\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# MSE: 437.9159827303376
# RMSE: 20.926442189974328
#         Date   Actual    Predicted
# 0 2022-01-03  1414.57  1435.185300
# 1 2022-01-04  1454.67  1419.108425
# 2 2022-01-05  1453.35  1446.924684
# 3 2022-01-06  1466.69  1435.509959
# 4 2022-01-07  1493.73  1445.216390

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 30

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head(10))

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 2625.1268890171254
# RMSE: 51.23599212484448
# MAE: 38.67354101214128
# R-squared: 0.9215229869086723
#         Date   Actual    Predicted
# 0 2022-01-03  1414.57  1450.357294
# 1 2022-01-04  1454.67  1445.236259
# 2 2022-01-05  1453.35  1456.529904
# 3 2022-01-06  1466.69  1454.016757
# 4 2022-01-07  1493.73  1455.999779
# 5 2022-01-10  1483.95  1463.216211
# 6 2022-01-11  1481.83  1460.271841
# 7 2022-01-12  1502.91  1459.674770
# 8 2022-01-13  1495.12  1465.776836
# 9 2022-01-14  1498.14  1464.412320

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 30

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 2625.1268890171254
# RMSE: 51.23599212484448
# MAE: 38.67354101214128
# R-squared: 0.9215229869086723
#         Date   Actual    Predicted
# 0 2022-01-03  1414.57  1450.357294
# 1 2022-01-04  1454.67  1445.236259
# 2 2022-01-05  1453.35  1456.529904
# 3 2022-01-06  1466.69  1454.016757
# 4 2022-01-07  1493.73  1455.999779

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/base_completa.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 30

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 2625.1268890171254
# RMSE: 51.23599212484448
# MAE: 38.67354101214128
# R-squared: 0.9215229869086723
#         Date   Actual    Predicted
# 0 2022-01-03  1414.57  1450.357294
# 1 2022-01-04  1454.67  1445.236259
# 2 2022-01-05  1453.35  1456.529904
# 3 2022-01-06  1466.69  1454.016757
# 4 2022-01-07  1493.73  1455.999779

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 1

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 301.1932506535949
# RMSE: 17.354920070504356
# MAE: 13.010816993464054
# R-squared: 0.9911526506555173
#         Date   Actual  Predicted
# 0 2022-01-04  1454.67    1414.57
# 1 2022-01-05  1453.35    1454.67
# 2 2022-01-06  1466.69    1453.35
# 3 2022-01-07  1493.73    1466.69
# 4 2022-01-11  1481.83    1483.95

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 1

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 301.1932506535949
# RMSE: 17.354920070504356
# MAE: 13.010816993464054
# R-squared: 0.9911526506555173
#         Date   Actual  Predicted
# 0 2022-01-04  1454.67    1414.57
# 1 2022-01-05  1453.35    1454.67
# 2 2022-01-06  1466.69    1453.35
# 3 2022-01-07  1493.73    1466.69
# 4 2022-01-11  1481.83    1483.95

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    total_days = len(data)
    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Define the window size for the EMA (1 day)
window_size = 1

# Perform walk-forward validation with EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

# Calculate error metrics
mse = mean_squared_error(actuals, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(actuals, predictions)
r2 = r2_score(actuals, predictions)

# Output the error metrics
print(f'MSE: {mse}')
print(f'RMSE: {rmse}')
print(f'MAE: {mae}')
print(f'R-squared: {r2}')

# Combine the actual and predicted values for comparison
results = pd.DataFrame({
    'Date': prediction_dates,
    'Actual': actuals,
    'Predicted': predictions
})

# Display the first few rows of the results
print(results.head())

# Plot the actual vs. predicted values
plt.figure(figsize=(12, 6))
plt.plot(results['Date'], results['Actual'], label='Actual', linestyle='-', marker='o')
plt.plot(results['Date'], results['Predicted'], label='Predicted', linestyle='-', marker='o')
plt.xlabel('Date')
plt.ylabel('Preco_Real')
plt.title('Actual vs. Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# MSE: 301.1932506535949
# RMSE: 17.354920070504356
# MAE: 13.010816993464054
# R-squared: 0.9911526506555173
#         Date   Actual  Predicted
# 0 2022-01-04  1454.67    1414.57
# 1 2022-01-05  1453.35    1454.67
# 2 2022-01-06  1466.69    1453.35
# 3 2022-01-07  1493.73    1466.69
# 4 2022-01-11  1481.83    1483.95

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# # Load the dataset
# df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# # Convert the Date column to datetime
# df['Date'] = pd.to_datetime(df['Date'])

# # Forward fill to handle missing values if there's any
# df.fillna(method='ffill', inplace=True)
# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Load the 'clima.csv' dataset
clima_df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

# Convert the Date column to datetime
clima_df['Date'] = pd.to_datetime(clima_df['Date'], errors='coerce')

# Drop rows where Date is NaT after conversion
clima_df = clima_df.dropna(subset=['Date'])

# Forward fill to handle missing values if there's any
clima_df.fillna(method='ffill', inplace=True)

# Perform walk-forward validation with EMA
window_size = 30  # Define the window size for the EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(clima_df, window_size)

# Calculate error metrics
mse_clima = mean_squared_error(actuals, predictions)
rmse_clima = np.sqrt(mse_clima)
mae_clima = mean_absolute_error(actuals, predictions)
r2_clima = r2_score(actuals, predictions)

# Output the error metrics
error_metrics_clima = {
    'MSE': mse_clima,
    'RMSE': rmse_clima,
    'MAE': mae_clima,
    'R-squared': r2_clima
}

error_metrics_clima
# Out:
# {'MSE': 2625.1268890171254,
#  'RMSE': 51.23599212484448,
#  'MAE': 38.67354101214128,
#  'R-squared': 0.9215229869086723}

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Load the 'clima.csv' dataset
clima_df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

# Convert the Date column to datetime
clima_df['Date'] = pd.to_datetime(clima_df['Date'], errors='coerce')

# Drop rows where Date is NaT after conversion
clima_df = clima_df.dropna(subset=['Date'])

# Forward fill to handle missing values if there's any
clima_df.fillna(method='ffill', inplace=True)

# Perform walk-forward validation with EMA
window_size = 30  # Define the window size for the EMA
prediction_dates, actuals, predictions = walk_forward_validation_ema(clima_df, window_size)

# Calculate error metrics
mse_clima = mean_squared_error(actuals, predictions)
rmse_clima = np.sqrt(mse_clima)
mae_clima = mean_absolute_error(actuals, predictions)
r2_clima = r2_score(actuals, predictions)

# Output the error metrics
error_metrics_clima = {
    'MSE': mse_clima,
    'RMSE': rmse_clima,
    'MAE': mae_clima,
    'R-squared': r2_clima
}

error_metrics_clima
# Out:
# {'MSE': 2625.1268890171254,
#  'RMSE': 51.23599212484448,
#  'MAE': 38.67354101214128,
#  'R-squared': 0.9215229869086723}

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# This function can then be used like so for each dataset:
# Load the dataset
df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv') # or '/mnt/data/clima.csv' for the other dataset

# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Drop rows where Date is NaT after conversion
df = df.dropna(subset=['Date'])

# Forward fill to handle missing values if there's any
df.fillna(method='ffill', inplace=True)

# Ensure 'Preco_Real' column exists to avoid KeyError
if 'Preco_Real' in df.columns:
    # Perform walk-forward validation with EMA
    window_size = 30
    prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

    # Calculate error metrics
    mse = mean_squared_error(actuals, predictions)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(actuals, predictions)
    r2 = r2_score(actuals, predictions)

    # The error metrics can then be printed or analyzed further

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Results storage
results = {}

# List of dataset file names
dataset_filenames = ['dolar.csv', 'clima.csv']

# Perform the analysis for each dataset
for filename in dataset_filenames:
    # Load the dataset
    df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/clima.csv')

    # Convert the Date column to datetime
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

    # Drop rows where Date is NaT after conversion
    df = df.dropna(subset=['Date'])

    # Forward fill to handle missing values if there's any
    df.fillna(method='ffill', inplace=True)

    # Check if 'Preco_Real' column exists
    if 'Preco_Real' in df.columns:
        # Perform walk-forward validation with EMA
        window_size = 30  # Define the window size for the EMA
        prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

        # Calculate error metrics
        mse = mean_squared_error(actuals, predictions)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(actuals, predictions)
        r2 = r2_score(actuals, predictions)

        # Store results
        results[filename] = {
            'mse': mse,
            'rmse': rmse,
            'mae': mae,
            'r2': r2
        }
    else:
        results[filename] = "The dataset does not contain 'Preco_Real' column."

# The results dictionary now contains the analysis results for each dataset
results
# Out:
# {'dolar.csv': {'mse': 2625.1268890171254,
#   'rmse': 51.23599212484448,
#   'mae': 38.67354101214128,
#   'r2': 0.9215229869086723},
#  'clima.csv': {'mse': 2625.1268890171254,
#   'rmse': 51.23599212484448,
#   'mae': 38.67354101214128,
#   'r2': 0.9215229869086723}}

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Function to perform walk-forward validation with EMA
def walk_forward_validation_ema(data, window_size=30):
    predictions = []
    actuals = []
    prediction_dates = []

    start_date = datetime(2022, 1, 1)
    end_date = datetime(2023, 8, 1)

    while start_date <= end_date:
        train_data = data[(data['Date'] >= start_date - timedelta(days=window_size)) & (data['Date'] < start_date)]['Preco_Real'].values
        val_data = data[data['Date'] == start_date]['Preco_Real'].values

        if len(train_data) > 0 and len(val_data) > 0:
            ema = train_data[-1]  # Initialize EMA with the last value of training data
            alpha = 2 / (window_size + 1)

            for val in train_data[::-1]:
                ema = alpha * val + (1 - alpha) * ema

            predictions.append(ema)
            actuals.append(val_data[0])
            prediction_dates.append(start_date)

        start_date += timedelta(days=1)

    return prediction_dates, actuals, predictions

# Results storage
results = {}

# List of dataset file names
dataset_filenames = ['dolar.csv', 'clima.csv']

# Perform the analysis for each dataset
for filename in dataset_filenames:
    # Load the dataset
    df = pd.read_csv('C:/Users/milen/OneDrive/Documentos/TCC/Bases/dolar.csv')

    # Convert the Date column to datetime
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

    # Drop rows where Date is NaT after conversion
    df = df.dropna(subset=['Date'])

    # Forward fill to handle missing values if there's any
    df.fillna(method='ffill', inplace=True)

    # Check if 'Preco_Real' column exists
    if 'Preco_Real' in df.columns:
        # Perform walk-forward validation with EMA
        window_size = 30  # Define the window size for the EMA
        prediction_dates, actuals, predictions = walk_forward_validation_ema(df, window_size)

        # Calculate error metrics
        mse = mean_squared_error(actuals, predictions)
        rmse = np.sqrt(mse)
        mae = mean_absolute_error(actuals, predictions)
        r2 = r2_score(actuals, predictions)

        # Store results
        results[filename] = {
            'mse': mse,
            'rmse': rmse,
            'mae': mae,
            'r2': r2
        }
    else:
        results[filename] = "The dataset does not contain 'Preco_Real' column."

# The results dictionary now contains the analysis results for each dataset
results
# Out:
# {'dolar.csv': {'mse': 2625.1268890171254,
#   'rmse': 51.23599212484448,
#   'mae': 38.67354101214128,
#   'r2': 0.9215229869086723},
#  'clima.csv': {'mse': 2625.1268890171254,
#   'rmse': 51.23599212484448,
#   'mae': 38.67354101214128,
#   'r2': 0.9215229869086723}}
